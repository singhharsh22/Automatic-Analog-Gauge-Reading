# %% [markdown]
# Considering the computation time and frame rate, so that the new frames are generated only after the older frame has been evaluated.
#
# This process enables real time video generation, and the intermediate frames encountered while the previous one is being evaluated are ditched.

# %%
from ultralytics import YOLO
import os
import cv2
import numpy as np
import easyocr
import math
from paddleocr import PaddleOCR
import time

# --------------------------
# Utility Functions
# --------------------------

def ocr_detect(reader, ocr, idx, x_center, y_center, radius, ocr_regions_folder, image, frame_id):
    """
    Detect and OCR the text in a circular region.
    For saving results we use the frame_id instead of an image path.
    """
    x_center, y_center, radius = int(x_center), int(y_center), int(radius)
    # Create a black mask with a white-filled circle.
    mask = np.zeros_like(image, dtype=np.uint8)
    cv2.circle(mask, (x_center, y_center), radius, (255, 255, 255), thickness=-1)
    circular_region = cv2.bitwise_and(image, image, mask=mask[:, :, 0])
    denoised = cv2.GaussianBlur(circular_region, (3, 3), 0)
    
    # Save the circular region for debugging purposes.
    denoised_path = os.path.join(ocr_regions_folder, f"denoised_circle_{idx}_frame_{frame_id}.jpg")
    cv2.imwrite(denoised_path, circular_region)
    print(f"Saved denoised circular region {idx} for frame {frame_id} to: {denoised_path}")

    result = ocr.ocr(denoised, cls=True)
    if result and result[0]:
        try:
            return float(result[0][0][1][0])
        except ValueError:
            print(f"PaddleOCR could not convert the text to float: {result[0][0][1][0]}")

    value = ""
    results = reader.readtext(denoised)
    for (bbox, text, confidence) in results:
        value += text
    try:
        return float(value)
    except ValueError:
        print(f"EasyOCR could not convert the text to float: {value}")
    return None

def rotate_point(point, angle_of_inclination):
    rotation_matrix = np.array([
        [math.cos(angle_of_inclination), -math.sin(angle_of_inclination)],
        [math.sin(angle_of_inclination), math.cos(angle_of_inclination)]
    ])
    return np.dot(rotation_matrix, point)

def stretch_point(point, major_axis_length, minor_axis_length):
    stretch_factor = major_axis_length / minor_axis_length
    return np.array([point[0] * stretch_factor, point[1]])

def get_angle(point1, point2, major_axis_length, minor_axis_length, ellipse_inclination):
    if point1 is None or point2 is None:
        return None
    # Rotate and stretch to compensate for elliptical distortion.
    rotated_point1 = rotate_point(point1, ellipse_inclination)
    rotated_point2 = rotate_point(point2, ellipse_inclination)
    stretched_point1 = stretch_point(rotated_point1, major_axis_length, minor_axis_length)
    stretched_point2 = stretch_point(rotated_point2, major_axis_length, minor_axis_length)

    # Calculate angle from point1 to point2.
    x1, y1 = point1
    x2, y2 = point2
    raw_angle = (math.atan2(y2 - y1, x2 - x1) + 2 * math.pi) % (2 * math.pi)
    ellipse_correction_factor = major_axis_length / minor_axis_length
    corrected_angle = (raw_angle * ellipse_correction_factor) % (2 * math.pi)
    return corrected_angle

def get_values(max_angle, min_angle, pointer_angle):
    """
    Based on the angles from the gauge, determine the range and the measured value's angle.
    """
    if min_angle < max_angle < pointer_angle:
        angle_range = 2 * math.pi - (max_angle - min_angle)
        val_angle = 2 * math.pi - (pointer_angle - min_angle)
        print('case (i) : ')
    elif pointer_angle < min_angle < max_angle:
        angle_range = 2 * math.pi - (max_angle - min_angle)
        val_angle = min_angle - pointer_angle
        print('case (ii) : ')
    elif max_angle < pointer_angle < min_angle:
        angle_range = min_angle - max_angle
        val_angle = min_angle - pointer_angle
        print('case (iii) : ')
    elif min_angle < pointer_angle < max_angle:
        angle_range = max_angle - min_angle
        val_angle = pointer_angle - min_angle
        print('case (iv) : ')
    elif pointer_angle < max_angle < min_angle:
        angle_range = 2 * math.pi - (min_angle - max_angle)
        val_angle = 2 * math.pi - (min_angle - pointer_angle)
        print('case (v) : ')
    elif max_angle < min_angle < pointer_angle:
        angle_range = 2 * math.pi - (min_angle - max_angle)
        val_angle = pointer_angle - min_angle
        print('case (vi) : ')
    else:
        angle_range = None
        val_angle = None
        print('case (vii) : ')
    
    print(f'angle_range = {math.degrees(angle_range) if angle_range is not None else None}')
    print(f'val_angle = {math.degrees(val_angle) if val_angle is not None else None}')
    return angle_range, val_angle

# --------------------------
# Main Frame Processing Function
# --------------------------

def process_frame(frame, frame_id, segmentation_model, detection_model, reader, ocr, ocr_regions_folder):
    height, width = frame.shape[:2]
    major_axis_length = None
    minor_axis_length = None

    # Run segmentation on the current frame.
    segmentation_results = segmentation_model(frame)
    segmented_image = frame.copy()

    if segmentation_results[0].masks is not None:
        masks = segmentation_results[0].masks.data.cpu().numpy()
        class_ids = segmentation_results[0].boxes.cls.cpu().numpy()
        clock_class_id = 74  # Adjust as needed.
        clock_mask = None
        for i in range(len(class_ids)):
            if int(class_ids[i]) == clock_class_id:
                clock_mask = masks[i]
                break
        if clock_mask is not None:
            clock_mask = (clock_mask * 255).astype(np.uint8)
            mask_resized = cv2.resize(clock_mask, (width, height), interpolation=cv2.INTER_LINEAR)
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
            cleaned_mask = cv2.morphologyEx(mask_resized, cv2.MORPH_CLOSE, kernel)
            cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_OPEN, kernel)
            contours, _ = cv2.findContours(cleaned_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            valid_contours = [c for c in contours if cv2.contourArea(c) > 500]
            if valid_contours:
                largest_contour = max(valid_contours, key=cv2.contourArea)
                ellipse = cv2.fitEllipse(largest_contour)
                center, axes, angle = ellipse
                major_axis_length = max(axes)
                minor_axis_length = min(axes)
                cv2.ellipse(segmented_image, ellipse, (0, 255, 0), 2)
                results = detection_model(segmented_image)
            else:
                print(f"No valid contours found in frame {frame_id}")
                results = detection_model(segmented_image)
        else:
            print(f"No 'clock' mask found in frame {frame_id}")
            results = detection_model(frame)
    else:
        print(f"No segmentation results for frame {frame_id}")
        results = detection_model(frame)

    # Initialize final_value before processing detection results.
    final_value = None

    if results is None:
        return frame, final_value

    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        confs = result.boxes.conf.cpu().numpy()
        labels = result.boxes.cls.cpu().numpy()
        label_centers = {}
        for i in range(len(labels)):
            label = int(labels[i])
            center_x = (boxes[i][0] + boxes[i][2]) / 2
            center_y = (boxes[i][1] + boxes[i][3]) / 2
            confidence = confs[i]
            if (label not in label_centers) or (confidence > label_centers[label]['confidence']):
                label_centers[label] = {'center': (center_x, center_y), 'confidence': confidence}
        for data in label_centers.values():
            cv2.circle(frame, (int(data['center'][0]), int(data['center'][1])), radius=5, color=(0, 255, 0), thickness=-1)

        pointer_base_1 = label_centers.get(0, {}).get('center', None)
        maximum_1 = label_centers.get(1, {}).get('center', None)
        minimum_1 = label_centers.get(2, {}).get('center', None)
        pointer_tip_1 = label_centers.get(3, {}).get('center', None)

        if pointer_base_1 is None or pointer_tip_1 is None or maximum_1 is None or minimum_1 is None:
            continue

        pointer_base = [pointer_base_1[0], height - pointer_base_1[1]]
        pointer_tip = [pointer_tip_1[0], height - pointer_tip_1[1]]
        maximum = [maximum_1[0], height - maximum_1[1]]
        minimum = [minimum_1[0], height - minimum_1[1]]

        cv2.circle(frame, (int(minimum_1[0]), int(minimum_1[1])), 
                   radius=int(major_axis_length/10) if major_axis_length else 5, color=(0, 0, 255), thickness=2)
        min_val = ocr_detect(reader, ocr, 0, minimum_1[0], minimum_1[1],
                             major_axis_length/9 if major_axis_length else 10, ocr_regions_folder, frame, frame_id)
        print(f"Frame {frame_id} - Minimum Value = {min_val}")

        cv2.circle(frame, (int(maximum_1[0]), int(maximum_1[1])), 
                   radius=int(major_axis_length/10) if major_axis_length else 5, color=(0, 0, 255), thickness=2)
        max_val = ocr_detect(reader, ocr, 1, maximum_1[0], maximum_1[1],
                             major_axis_length/9 if major_axis_length else 10, ocr_regions_folder, frame, frame_id)
        print(f"Frame {frame_id} - Maximum Value = {max_val}")

        ellipse_inclination = angle if 'angle' in locals() else 0

        min_angle = get_angle(pointer_base, minimum, 
                              major_axis_length if major_axis_length else 1, 
                              minor_axis_length if minor_axis_length else 1, ellipse_inclination)
        max_angle = get_angle(pointer_base, maximum, 
                              major_axis_length if major_axis_length else 1, 
                              minor_axis_length if minor_axis_length else 1, ellipse_inclination)
        pointer_angle = get_angle(pointer_base, pointer_tip, 
                                  major_axis_length if major_axis_length else 1, 
                                  minor_axis_length if minor_axis_length else 1, ellipse_inclination)
        if None not in (min_angle, max_angle, pointer_angle) and (max_val is not None) and (min_val is not None):
            print(f"Frame {frame_id} - min_angle = {math.degrees(min_angle)}")
            print(f"Frame {frame_id} - max_angle = {math.degrees(max_angle)}")
            print(f"Frame {frame_id} - pointer_angle = {math.degrees(pointer_angle)}")
            angle_range, val_angle = get_values(max_angle, min_angle, pointer_angle)
            if angle_range is not None and val_angle is not None:
                final_value = ((max_val - min_val) * val_angle) / angle_range
                print(f"Frame {frame_id} - Final Gauge Reading = {final_value}")
                # cv2.putText(frame, f"Gauge: {final_value:.2f}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # --------------------------
        # Add Text Box at Bottom Right
        # --------------------------
        text = f"Detected Reading : {final_value:.2f}" if final_value is not None else "Detected Reading : N/A"
        (text_width, text_height), _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.8, 2)
        margin = 10
        x_box = frame.shape[1] - text_width - margin
        y_box = frame.shape[0] - margin
        cv2.rectangle(frame, (x_box - 5, y_box - text_height - 5), (x_box + text_width + 5, y_box + 5), (0, 0, 0), thickness=-1)
        cv2.putText(frame, text, (x_box, y_box), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
        # --------------------------

    return frame, final_value

# --------------------------
# Main Video Processing Loop
# --------------------------

def main():
    # Load your YOLO models.
    segmentation_model = YOLO("yolo11n-seg.pt")
    detection_model = YOLO("C:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\pretrained_models\\4\\last.pt")
    
    # Define output folders for results and OCR regions.
    global output_folder
    output_folder = "C:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\result_frames_video"
    os.makedirs(output_folder, exist_ok=True)
    ocr_regions_folder = "C:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\ocr_regions_video"
    os.makedirs(ocr_regions_folder, exist_ok=True)

    # Initialize OCR readers.
    reader = easyocr.Reader(['en'], gpu=True)
    ocr = PaddleOCR(use_angle_cls=True, lang='en', rec=True, device='cpu')
    
    # Open a video file or webcam stream (use 0 for webcam).
    cap = cv2.VideoCapture("C:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\test_videos\\195199132_main_xxl.mp4")
    # cap = cv2.VideoCapture(0)
    

    # Set up video writer using the same properties as the input video.
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter("C:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\result_frames_video\\final_output_2.mp4", 
                        fourcc, fps, (width, height))
    if not out.isOpened():
        print("Error: VideoWriter not opened!")

    frame_id = 0
    last_frame_time = 0  # Keep track of the timestamp of the last processed frame.
    while True:
        start_time = time.time()
        
        ret, frame = cap.read()
        if not ret:
            break
        frame_id += 1

        # Process the frame.
        processed_frame, gauge_value = process_frame(frame, frame_id, segmentation_model, detection_model, reader, ocr, ocr_regions_folder)
        
        # Display the processed frame.
        cv2.imshow("Gauge Reading", processed_frame)
        
        # Calculate elapsed processing time and determine frames to skip.
        processing_time = time.time() - start_time
        frames_to_skip = int(processing_time * fps)
        
        # Instead of just skipping, duplicate the processed frame for the number of skipped frames + 1.
        duplicate_count = frames_to_skip + 1
        for _ in range(duplicate_count):
            out.write(processed_frame)
        
        # Skip frames without processing.
        for _ in range(frames_to_skip):
            cap.grab()  # Grab without decoding.
            
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

if __name__ == '__main__':
    main()
# Out:
# [2025/06/06 12:56:15] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Harsh/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Harsh/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\Harsh\\Desktop\\PTZ Camera Zoom with Gauge Detection\\venv1\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\Harsh/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2', device='cpu')
#
# 0: 384x640 1 clock, 78.4ms
# Speed: 3.1ms preprocess, 78.4ms inference, 88.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 1 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_1.jpg
# [2025/06/06 12:56:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.403170108795166
# [2025/06/06 12:56:17] ppocr DEBUG: cls num  : 1, elapsed : 0.029520750045776367
# [2025/06/06 12:56:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10416007041931152
# Frame 1 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 1 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_1.jpg
# [2025/06/06 12:56:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11333918571472168
# [2025/06/06 12:56:17] ppocr DEBUG: cls num  : 1, elapsed : 0.004067897796630859
# [2025/06/06 12:56:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05330014228820801
# Frame 1 - Maximum Value = 60.0
# Frame 1 - min_angle = 253.5045594074683
# Frame 1 - max_angle = 356.2195903036968
# Frame 1 - pointer_angle = 225.16482462762747
# case (ii) :
# angle_range = 257.28496910377146
# val_angle = 28.33973477984082
# Frame 1 - Final Gauge Reading = 6.608952294079133
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 4 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_4.jpg
# [2025/06/06 12:56:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11256027221679688
# [2025/06/06 12:56:18] ppocr DEBUG: cls num  : 1, elapsed : 0.003996849060058594
# [2025/06/06 12:56:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05232858657836914
# Frame 4 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 4 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_4.jpg
# [2025/06/06 12:56:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.111419677734375
# [2025/06/06 12:56:18] ppocr DEBUG: cls num  : 1, elapsed : 0.0040056705474853516
# [2025/06/06 12:56:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051517486572265625
# Frame 4 - Maximum Value = 60.0
# Frame 4 - min_angle = 251.33661060440153
# Frame 4 - max_angle = 350.7685842132013
# Frame 4 - pointer_angle = 193.32401946606663
# case (ii) :
# angle_range = 260.56802639120025
# val_angle = 58.01259113833491
# Frame 4 - Final Gauge Reading = 13.358336847800008
#
# 0: 384x640 1 clock, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 5 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_5.jpg
# [2025/06/06 12:56:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1172780990600586
# [2025/06/06 12:56:18] ppocr DEBUG: cls num  : 1, elapsed : 0.005004405975341797
# [2025/06/06 12:56:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051519155502319336
# Frame 5 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 5 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_5.jpg
# [2025/06/06 12:56:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11019372940063477
# [2025/06/06 12:56:18] ppocr DEBUG: cls num  : 1, elapsed : 0.00400090217590332
# [2025/06/06 12:56:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05129075050354004
# Frame 5 - Maximum Value = 60.0
# Frame 5 - min_angle = 250.8118017847699
# Frame 5 - max_angle = 349.9928796177603
# Frame 5 - pointer_angle = 186.7119767590787
# case (ii) :
# angle_range = 260.8189221670096
# val_angle = 64.0998250256912
# Frame 5 - Final Gauge Reading = 14.74582238737563
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 6 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_6.jpg
# [2025/06/06 12:56:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11157941818237305
# [2025/06/06 12:56:18] ppocr DEBUG: cls num  : 1, elapsed : 0.005007505416870117
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05100440979003906
# Frame 6 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 6 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_6.jpg
# [2025/06/06 12:56:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1114346981048584
# [2025/06/06 12:56:19] ppocr DEBUG: cls num  : 1, elapsed : 0.004006147384643555
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051340341567993164
# Frame 6 - Maximum Value = 60.0
# Frame 6 - min_angle = 250.16520691559055
# Frame 6 - max_angle = 349.1987127979114
# Frame 6 - pointer_angle = 179.2182483687839
# case (ii) :
# angle_range = 260.96649411767913
# val_angle = 70.94695854680666
# Frame 6 - Final Gauge Reading = 16.311739662980827
#
# 0: 384x640 1 clock, 11.1ms
# Speed: 1.1ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 7 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_7.jpg
# [2025/06/06 12:56:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11141252517700195
# [2025/06/06 12:56:19] ppocr DEBUG: cls num  : 1, elapsed : 0.004182577133178711
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052158355712890625
# Frame 7 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 7 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_7.jpg
# [2025/06/06 12:56:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11041784286499023
# [2025/06/06 12:56:19] ppocr DEBUG: cls num  : 1, elapsed : 0.004004240036010742
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05128931999206543
# Frame 7 - Maximum Value = 60.0
# Frame 7 - min_angle = 249.77876485124597
# Frame 7 - max_angle = 348.82334063727956
# Frame 7 - pointer_angle = 173.36331723301416
# case (ii) :
# angle_range = 260.9554242139664
# val_angle = 76.41544761823184
# Frame 7 - Final Gauge Reading = 17.5697702812821
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 8 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_8.jpg
# [2025/06/06 12:56:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11195087432861328
# [2025/06/06 12:56:19] ppocr DEBUG: cls num  : 1, elapsed : 0.0039997100830078125
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05128908157348633
# Frame 8 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 8 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_8.jpg
# [2025/06/06 12:56:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11019349098205566
# [2025/06/06 12:56:19] ppocr DEBUG: cls num  : 1, elapsed : 0.004007101058959961
# [2025/06/06 12:56:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051665306091308594
# Frame 8 - Maximum Value = 60.0
# Frame 8 - min_angle = 249.91541827975286
# Frame 8 - max_angle = 348.60867312357414
# Frame 8 - pointer_angle = 166.8695687786865
# case (ii) :
# angle_range = 261.30674515617875
# val_angle = 83.04584950106636
# Frame 8 - Final Gauge Reading = 19.068589167439495
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 9 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_9.jpg
# [2025/06/06 12:56:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11282825469970703
# [2025/06/06 12:56:20] ppocr DEBUG: cls num  : 1, elapsed : 0.0051593780517578125
# [2025/06/06 12:56:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051763296127319336
# Frame 9 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 9 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_9.jpg
# [2025/06/06 12:56:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10973978042602539
# [2025/06/06 12:56:20] ppocr DEBUG: cls num  : 1, elapsed : 0.004004955291748047
# [2025/06/06 12:56:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05137062072753906
# Frame 9 - Maximum Value = 60.0
# Frame 9 - min_angle = 250.56582832679817
# Frame 9 - max_angle = 349.5088087617314
# Frame 9 - pointer_angle = 160.86028060606185
# case (ii) :
# angle_range = 261.05701956506675
# val_angle = 89.7055477207363
# Frame 9 - Final Gauge Reading = 20.617460783898466
#
# 0: 384x640 1 clock, 10.1ms
# Speed: 1.1ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 2 tips, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 10 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_10.jpg
# [2025/06/06 12:56:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11259055137634277
# [2025/06/06 12:56:20] ppocr DEBUG: cls num  : 1, elapsed : 0.004006385803222656
# [2025/06/06 12:56:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052297353744506836
# Frame 10 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 10 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_10.jpg
# [2025/06/06 12:56:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11054134368896484
# [2025/06/06 12:56:20] ppocr DEBUG: cls num  : 1, elapsed : 0.004010677337646484
# [2025/06/06 12:56:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05153226852416992
# Frame 10 - Maximum Value = 60.0
# Frame 10 - min_angle = 250.71877813645378
# Frame 10 - max_angle = 349.9120106364778
# Frame 10 - pointer_angle = 154.59546232987418
# case (ii) :
# angle_range = 260.80676749997593
# val_angle = 96.12331580657958
# Frame 10 - Final Gauge Reading = 22.11368594335002
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 11 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_11.jpg
# [2025/06/06 12:56:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11092114448547363
# [2025/06/06 12:56:20] ppocr DEBUG: cls num  : 1, elapsed : 0.0050048828125
# [2025/06/06 12:56:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05030369758605957
# Frame 11 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 11 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_11.jpg
# [2025/06/06 12:56:21] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10915350914001465
# [2025/06/06 12:56:21] ppocr DEBUG: cls num  : 1, elapsed : 0.004166841506958008
# [2025/06/06 12:56:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050362348556518555
# Frame 11 - Maximum Value = 60.0
# Frame 11 - min_angle = 250.29064881210633
# Frame 11 - max_angle = 349.24792706869437
# Frame 11 - pointer_angle = 148.28471345190556
# case (ii) :
# angle_range = 261.04272174341196
# val_angle = 102.00593536020074
# Frame 11 - Final Gauge Reading = 23.445802590228727
#
# 0: 384x640 1 clock, 26.3ms
# Speed: 3.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 12 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_12.jpg
# [2025/06/06 12:56:21] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11192703247070312
# [2025/06/06 12:56:21] ppocr DEBUG: cls num  : 1, elapsed : 0.004011869430541992
# [2025/06/06 12:56:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05049943923950195
# Frame 12 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 12 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_12.jpg
# [2025/06/06 12:56:21] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11044454574584961
# [2025/06/06 12:56:21] ppocr DEBUG: cls num  : 1, elapsed : 0.003999948501586914
# [2025/06/06 12:56:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05028700828552246
# Frame 12 - Maximum Value = 60.0
# Frame 12 - min_angle = 251.3383055889874
# Frame 12 - max_angle = 351.0058682557353
# Frame 12 - pointer_angle = 142.9611798779165
# case (ii) :
# angle_range = 260.3324373332521
# val_angle = 108.37712571107092
# Frame 12 - Final Gauge Reading = 24.978168718714944
#
# 0: 384x640 1 clock, 53.8ms
# Speed: 3.0ms preprocess, 53.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 13 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_13.jpg
# [2025/06/06 12:56:21] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11167502403259277
# [2025/06/06 12:56:21] ppocr DEBUG: cls num  : 1, elapsed : 0.005010843276977539
# [2025/06/06 12:56:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052130937576293945
# Frame 13 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 13 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_13.jpg
# [2025/06/06 12:56:22] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11422181129455566
# [2025/06/06 12:56:22] ppocr DEBUG: cls num  : 1, elapsed : 0.005014181137084961
# [2025/06/06 12:56:22] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05237436294555664
# Frame 13 - Maximum Value = 60.0
# Frame 13 - min_angle = 253.6341725091941
# Frame 13 - max_angle = 354.1556673404756
# Frame 13 - pointer_angle = 137.91341039751953
# case (ii) :
# angle_range = 259.4785051687185
# val_angle = 115.72076211167456
# Frame 13 - Final Gauge Reading = 26.758462024381657
#
# 0: 384x640 1 clock, 51.2ms
# Speed: 4.0ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 14 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_14.jpg
# [2025/06/06 12:56:22] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11286473274230957
# [2025/06/06 12:56:22] ppocr DEBUG: cls num  : 1, elapsed : 0.004006862640380859
# [2025/06/06 12:56:22] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050305843353271484
# Frame 14 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 14 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_14.jpg
# [2025/06/06 12:56:22] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11151599884033203
# [2025/06/06 12:56:22] ppocr DEBUG: cls num  : 1, elapsed : 0.005007266998291016
# [2025/06/06 12:56:22] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052118539810180664
# Frame 14 - Maximum Value = 60.0
# Frame 14 - min_angle = 252.65504319534114
# Frame 14 - max_angle = 352.16673173901074
# Frame 14 - pointer_angle = 129.47835049374092
# case (ii) :
# angle_range = 260.4883114563304
# val_angle = 123.17669270160023
# Frame 14 - Final Gauge Reading = 28.372104378798632
#
# 0: 384x640 1 clock, 51.3ms
# Speed: 2.9ms preprocess, 51.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 15 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_15.jpg
# [2025/06/06 12:56:22] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11046266555786133
# [2025/06/06 12:56:22] ppocr DEBUG: cls num  : 1, elapsed : 0.003996610641479492
# [2025/06/06 12:56:22] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05211329460144043
# Frame 15 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 15 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_15.jpg
# [2025/06/06 12:56:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10865044593811035
# [2025/06/06 12:56:23] ppocr DEBUG: cls num  : 1, elapsed : 0.004997730255126953
# [2025/06/06 12:56:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05033063888549805
# Frame 15 - Maximum Value = 60.0
# Frame 15 - min_angle = 252.3221649437126
# Frame 15 - max_angle = 351.86445137131585
# Frame 15 - pointer_angle = 122.36473625136448
# case (ii) :
# angle_range = 260.45771357239676
# val_angle = 129.95742869234812
# Frame 15 - Final Gauge Reading = 29.93747282271796
#
# 0: 384x640 1 clock, 49.1ms
# Speed: 4.0ms preprocess, 49.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 34.2ms
# Speed: 2.9ms preprocess, 34.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 16 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_16.jpg
# [2025/06/06 12:56:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11106610298156738
# [2025/06/06 12:56:23] ppocr DEBUG: cls num  : 1, elapsed : 0.004228353500366211
# [2025/06/06 12:56:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0514521598815918
# Frame 16 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 16 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_16.jpg
# [2025/06/06 12:56:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11130714416503906
# [2025/06/06 12:56:23] ppocr DEBUG: cls num  : 1, elapsed : 0.005099773406982422
# [2025/06/06 12:56:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05149507522583008
# Frame 16 - Maximum Value = 60.0
# Frame 16 - min_angle = 252.74334795608306
# Frame 16 - max_angle = 352.94096402336595
# Frame 16 - pointer_angle = 115.59418664991043
# case (ii) :
# angle_range = 259.8023839327171
# val_angle = 137.14916130617266
# Frame 16 - Final Gauge Reading = 31.673880561856077
#
# 0: 384x640 1 clock, 50.2ms
# Speed: 3.0ms preprocess, 50.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 17 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_17.jpg
# [2025/06/06 12:56:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11520504951477051
# [2025/06/06 12:56:23] ppocr DEBUG: cls num  : 1, elapsed : 0.004000425338745117
# [2025/06/06 12:56:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.053224802017211914
# Frame 17 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 17 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_17.jpg
# [2025/06/06 12:56:24] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11179995536804199
# [2025/06/06 12:56:24] ppocr DEBUG: cls num  : 1, elapsed : 0.004124641418457031
# [2025/06/06 12:56:24] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05040097236633301
# Frame 17 - Maximum Value = 60.0
# Frame 17 - min_angle = 255.00180995464117
# Frame 17 - max_angle = 356.58359226435545
# Frame 17 - pointer_angle = 111.70759126908587
# case (ii) :
# angle_range = 258.4182176902857
# val_angle = 143.2942186855553
# Frame 17 - Final Gauge Reading = 33.27030577789066
#
# 0: 384x640 1 clock, 24.3ms
# Speed: 2.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 17.1ms
# Speed: 1.1ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 18 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_18.jpg
# [2025/06/06 12:56:24] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.109710693359375
# [2025/06/06 12:56:24] ppocr DEBUG: cls num  : 1, elapsed : 0.004064083099365234
# [2025/06/06 12:56:24] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05121159553527832
# Frame 18 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 18 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_18.jpg
# [2025/06/06 12:56:24] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10880446434020996
# [2025/06/06 12:56:24] ppocr DEBUG: cls num  : 1, elapsed : 0.004141092300415039
# [2025/06/06 12:56:24] ppocr DEBUG: rec_res num  : 1, elapsed : 0.053258419036865234
# Frame 18 - Maximum Value = 60.0
# Frame 18 - min_angle = 253.76386209154836
# Frame 18 - max_angle = 354.94243881248093
# Frame 18 - pointer_angle = 102.49689544301508
# case (ii) :
# angle_range = 258.82142327906746
# val_angle = 151.2669666485333
# Frame 18 - Final Gauge Reading = 35.06671852710592
#
# 0: 384x640 1 clock, 24.2ms
# Speed: 2.0ms preprocess, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 19 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_19.jpg
# [2025/06/06 12:56:24] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11260247230529785
# [2025/06/06 12:56:24] ppocr DEBUG: cls num  : 1, elapsed : 0.004982709884643555
# [2025/06/06 12:56:24] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05312371253967285
# Frame 19 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 19 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_19.jpg
# [2025/06/06 12:56:24] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11621356010437012
# [2025/06/06 12:56:24] ppocr DEBUG: cls num  : 1, elapsed : 0.005001068115234375
# [2025/06/06 12:56:24] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05321240425109863
# Frame 19 - Maximum Value = 60.0
# Frame 19 - min_angle = 253.41761776092943
# Frame 19 - max_angle = 354.35947942024757
# Frame 19 - pointer_angle = 93.6982234645148
# case (ii) :
# angle_range = 259.05813834068186
# val_angle = 159.7193942964146
# Frame 19 - Final Gauge Reading = 36.99232812822217
#
# 0: 384x640 1 clock, 24.1ms
# Speed: 3.1ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 20 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_20.jpg
# [2025/06/06 12:56:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11473870277404785
# [2025/06/06 12:56:25] ppocr DEBUG: cls num  : 1, elapsed : 0.004944562911987305
# [2025/06/06 12:56:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052469730377197266
# EasyOCR could not convert the text to float:
# Frame 20 - Minimum Value = None
# Saved denoised circular region 1 for frame 20 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_20.jpg
# [2025/06/06 12:56:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.12360548973083496
# [2025/06/06 12:56:25] ppocr DEBUG: cls num  : 1, elapsed : 0.005109548568725586
# [2025/06/06 12:56:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052248477935791016
# Frame 20 - Maximum Value = 60.0
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 1.2ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 21 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_21.jpg
# [2025/06/06 12:56:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1114053726196289
# [2025/06/06 12:56:25] ppocr DEBUG: cls num  : 1, elapsed : 0.004006862640380859
# [2025/06/06 12:56:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050942420959472656
# Frame 21 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 21 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_21.jpg
# [2025/06/06 12:56:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11091399192810059
# [2025/06/06 12:56:26] ppocr DEBUG: cls num  : 1, elapsed : 0.005145549774169922
# [2025/06/06 12:56:26] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0515596866607666
# Frame 21 - Maximum Value = 60.0
# Frame 21 - min_angle = 250.2045947589415
# Frame 21 - max_angle = 350.0705122557842
# Frame 21 - pointer_angle = 77.85515536215388
# case (ii) :
# angle_range = 260.13408250315734
# val_angle = 172.34943939678763
# Frame 21 - Final Gauge Reading = 39.75244713918541
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 0.9ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 22 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_22.jpg
# [2025/06/06 12:56:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11374330520629883
# [2025/06/06 12:56:26] ppocr DEBUG: cls num  : 1, elapsed : 0.004100799560546875
# [2025/06/06 12:56:26] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05160355567932129
# Frame 22 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 22 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_22.jpg
# [2025/06/06 12:56:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10990285873413086
# [2025/06/06 12:56:26] ppocr DEBUG: cls num  : 1, elapsed : 0.004151821136474609
# [2025/06/06 12:56:26] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0504755973815918
# Frame 22 - Maximum Value = 60.0
# Frame 22 - min_angle = 247.24402357949455
# Frame 22 - max_angle = 345.97801565648655
# Frame 22 - pointer_angle = 67.27334057172656
# case (ii) :
# angle_range = 261.26600792300803
# val_angle = 179.970683007768
# Frame 22 - Final Gauge Reading = 41.33044733338672
#
# 0: 384x640 1 clock, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 23 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_23.jpg
# [2025/06/06 12:56:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11039280891418457
# [2025/06/06 12:56:27] ppocr DEBUG: cls num  : 1, elapsed : 0.004007577896118164
# [2025/06/06 12:56:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05029892921447754
# EasyOCR could not convert the text to float:
# Frame 23 - Minimum Value = None
# Saved denoised circular region 1 for frame 23 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_23.jpg
# [2025/06/06 12:56:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11443877220153809
# [2025/06/06 12:56:27] ppocr DEBUG: cls num  : 1, elapsed : 0.003999471664428711
# [2025/06/06 12:56:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05233597755432129
# Frame 23 - Maximum Value = 60.0
#
# 0: 384x640 1 clock, 10.3ms
# Speed: 2.0ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 24 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_24.jpg
# [2025/06/06 12:56:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11337995529174805
# [2025/06/06 12:56:27] ppocr DEBUG: cls num  : 1, elapsed : 0.005007028579711914
# [2025/06/06 12:56:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.053008079528808594
# EasyOCR could not convert the text to float:
# Frame 24 - Minimum Value = None
# Saved denoised circular region 1 for frame 24 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_24.jpg
# [2025/06/06 12:56:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11223053932189941
# [2025/06/06 12:56:27] ppocr DEBUG: cls num  : 1, elapsed : 0.003999233245849609
# [2025/06/06 12:56:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05165410041809082
# Frame 24 - Maximum Value = 60.0
#
# 0: 384x640 1 clock, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 2 tips, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 25 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_25.jpg
# [2025/06/06 12:56:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1152791976928711
# [2025/06/06 12:56:28] ppocr DEBUG: cls num  : 1, elapsed : 0.003992319107055664
# [2025/06/06 12:56:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05299711227416992
# Frame 25 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 25 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_25.jpg
# [2025/06/06 12:56:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10996627807617188
# [2025/06/06 12:56:28] ppocr DEBUG: cls num  : 1, elapsed : 0.005180835723876953
# [2025/06/06 12:56:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05121493339538574
# Frame 25 - Maximum Value = 60.0
# Frame 25 - min_angle = 245.86237468129985
# Frame 25 - max_angle = 343.8304325753361
# Frame 25 - pointer_angle = 42.961238686461506
# case (ii) :
# angle_range = 262.03194210596376
# val_angle = 202.90113599483834
# Frame 25 - Final Gauge Reading = 46.46024473904483
#
# 0: 384x640 1 clock, 9.9ms
# Speed: 2.0ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 26 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_26.jpg
# [2025/06/06 12:56:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1123342514038086
# [2025/06/06 12:56:28] ppocr DEBUG: cls num  : 1, elapsed : 0.004003286361694336
# [2025/06/06 12:56:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051390886306762695
# Frame 26 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 26 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_26.jpg
# [2025/06/06 12:56:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11207938194274902
# [2025/06/06 12:56:28] ppocr DEBUG: cls num  : 1, elapsed : 0.0040094852447509766
# [2025/06/06 12:56:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052551984786987305
# Frame 26 - Maximum Value = 60.0
# Frame 26 - min_angle = 246.01397041712139
# Frame 26 - max_angle = 344.20461044494925
# Frame 26 - pointer_angle = 36.40400568904548
# case (ii) :
# angle_range = 261.80935997217216
# val_angle = 209.6099647280759
# Frame 26 - Final Gauge Reading = 48.03723550991961
#
# 0: 384x640 1 clock, 10.2ms
# Speed: 1.1ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 27 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_27.jpg
# [2025/06/06 12:56:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11118578910827637
# [2025/06/06 12:56:29] ppocr DEBUG: cls num  : 1, elapsed : 0.003999471664428711
# [2025/06/06 12:56:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05239725112915039
# Frame 27 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 27 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_27.jpg
# [2025/06/06 12:56:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11194825172424316
# [2025/06/06 12:56:29] ppocr DEBUG: cls num  : 1, elapsed : 0.006133556365966797
# [2025/06/06 12:56:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05094313621520996
# Frame 27 - Maximum Value = 60.0
# Frame 27 - min_angle = 247.74738210263675
# Frame 27 - max_angle = 346.6454092886269
# Frame 27 - pointer_angle = 30.56539279899037
# case (ii) :
# angle_range = 261.1019728140098
# val_angle = 217.18198930364636
# Frame 27 - Final Gauge Reading = 49.90739525166694
#
# 0: 384x640 1 clock, 10.2ms
# Speed: 1.0ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.2ms
# Speed: 1.0ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 28 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_28.jpg
# [2025/06/06 12:56:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11295342445373535
# [2025/06/06 12:56:29] ppocr DEBUG: cls num  : 1, elapsed : 0.004197835922241211
# [2025/06/06 12:56:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050814151763916016
# Frame 28 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 28 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_28.jpg
# [2025/06/06 12:56:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.111053466796875
# [2025/06/06 12:56:29] ppocr DEBUG: cls num  : 1, elapsed : 0.005120992660522461
# [2025/06/06 12:56:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05129241943359375
# Frame 28 - Maximum Value = 60.0
# Frame 28 - min_angle = 247.33448466251855
# Frame 28 - max_angle = 345.7281433405097
# Frame 28 - pointer_angle = 24.89426925953401
# case (ii) :
# angle_range = 261.60634132200886
# val_angle = 222.44021540298453
# Frame 28 - Final Gauge Reading = 51.01716134530201
#
# 0: 384x640 1 clock, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 10.0ms
# Speed: 1.1ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 29 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_29.jpg
# [2025/06/06 12:56:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11273455619812012
# [2025/06/06 12:56:29] ppocr DEBUG: cls num  : 1, elapsed : 0.004212141036987305
# [2025/06/06 12:56:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051444053649902344
# Frame 29 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 29 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_29.jpg
# [2025/06/06 12:56:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11175704002380371
# [2025/06/06 12:56:30] ppocr DEBUG: cls num  : 1, elapsed : 0.003999948501586914
# [2025/06/06 12:56:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05134296417236328
# Frame 29 - Maximum Value = 60.0
# Frame 29 - min_angle = 245.48219555145255
# Frame 29 - max_angle = 343.7068130543271
# Frame 29 - pointer_angle = 18.4151390553524
# case (ii) :
# angle_range = 261.77538249712546
# val_angle = 227.06705649610015
# Frame 29 - Final Gauge Reading = 52.04470817616172
#
# 0: 384x640 1 clock, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 30 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_30.jpg
# [2025/06/06 12:56:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11105036735534668
# [2025/06/06 12:56:30] ppocr DEBUG: cls num  : 1, elapsed : 0.00440669059753418
# [2025/06/06 12:56:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05139970779418945
# Frame 30 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 30 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_30.jpg
# [2025/06/06 12:56:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1089930534362793
# [2025/06/06 12:56:30] ppocr DEBUG: cls num  : 1, elapsed : 0.0049974918365478516
# [2025/06/06 12:56:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051569223403930664
# Frame 30 - Maximum Value = 60.0
# Frame 30 - min_angle = 245.68739404457983
# Frame 30 - max_angle = 344.07074516090546
# Frame 30 - pointer_angle = 13.853387309472081
# case (ii) :
# angle_range = 261.6166488836744
# val_angle = 231.83400673510775
# Frame 30 - Final Gauge Reading = 53.16955348010534
#
# 0: 384x640 1 clock, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 8.9ms
# Speed: 1.0ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 31 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_31.jpg
# [2025/06/06 12:56:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11198043823242188
# [2025/06/06 12:56:30] ppocr DEBUG: cls num  : 1, elapsed : 0.00439906120300293
# [2025/06/06 12:56:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05040240287780762
# Frame 31 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 31 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_31.jpg
# [2025/06/06 12:56:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10946917533874512
# [2025/06/06 12:56:30] ppocr DEBUG: cls num  : 1, elapsed : 0.004996538162231445
# [2025/06/06 12:56:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05152249336242676
# Frame 31 - Maximum Value = 60.0
# Frame 31 - min_angle = 245.52120300051294
# Frame 31 - max_angle = 343.5562338015873
# Frame 31 - pointer_angle = 8.44249495451002
# case (ii) :
# angle_range = 261.96496919892564
# val_angle = 237.07870804600293
# Frame 31 - Final Gauge Reading = 54.300094116624024
#
# 0: 384x640 1 clock, 12.0ms
# Speed: 1.9ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 32 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_32.jpg
# [2025/06/06 12:56:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10901379585266113
# [2025/06/06 12:56:31] ppocr DEBUG: cls num  : 1, elapsed : 0.004980325698852539
# [2025/06/06 12:56:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051084041595458984
# Frame 32 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 32 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_32.jpg
# [2025/06/06 12:56:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10591793060302734
# [2025/06/06 12:56:31] ppocr DEBUG: cls num  : 1, elapsed : 0.0039899349212646484
# [2025/06/06 12:56:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050586700439453125
# Frame 32 - Maximum Value = 60.0
# Frame 32 - min_angle = 245.46576377103358
# Frame 32 - max_angle = 343.60254716453295
# Frame 32 - pointer_angle = 4.380018078343045
# case (ii) :
# angle_range = 261.8632166065006
# val_angle = 241.08574569269052
# Frame 32 - Final Gauge Reading = 55.23931512419351
#
# 0: 384x640 1 clock, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 33 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_33.jpg
# [2025/06/06 12:56:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11073493957519531
# [2025/06/06 12:56:31] ppocr DEBUG: cls num  : 1, elapsed : 0.0040073394775390625
# [2025/06/06 12:56:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05041790008544922
# Frame 33 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 33 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_33.jpg
# [2025/06/06 12:56:32] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10788536071777344
# [2025/06/06 12:56:32] ppocr DEBUG: cls num  : 1, elapsed : 0.00413823127746582
# [2025/06/06 12:56:32] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05045151710510254
# Frame 33 - Maximum Value = 60.0
# Frame 33 - min_angle = 245.42245146434743
# Frame 33 - max_angle = 343.228945615399
# Frame 33 - pointer_angle = 27.38592574058434
# case (ii) :
# angle_range = 262.1935058489484
# val_angle = 218.0365257237631
# Frame 33 - Final Gauge Reading = 49.895177613447565
#
# 0: 384x640 1 clock, 10.2ms
# Speed: 0.9ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 34 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_34.jpg
# [2025/06/06 12:56:32] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10912537574768066
# [2025/06/06 12:56:32] ppocr DEBUG: cls num  : 1, elapsed : 0.0039997100830078125
# [2025/06/06 12:56:32] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05133366584777832
# Frame 34 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 34 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_34.jpg
# [2025/06/06 12:56:32] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10875058174133301
# [2025/06/06 12:56:32] ppocr DEBUG: cls num  : 1, elapsed : 0.004990816116333008
# [2025/06/06 12:56:32] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04987025260925293
# Frame 34 - Maximum Value = 60.0
# Frame 34 - min_angle = 245.58772451777827
# Frame 34 - max_angle = 343.6138301505242
# Frame 34 - pointer_angle = 23.265967459590694
# case (ii) :
# angle_range = 261.97389436725405
# val_angle = 222.3217570581876
# Frame 34 - Final Gauge Reading = 50.91845298444603
#
# 0: 384x640 1 clock, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 35 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_35.jpg
# [2025/06/06 12:56:32] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11057281494140625
# [2025/06/06 12:56:32] ppocr DEBUG: cls num  : 1, elapsed : 0.004207134246826172
# [2025/06/06 12:56:32] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051279306411743164
# Frame 35 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 35 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_35.jpg
# [2025/06/06 12:56:32] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10869956016540527
# [2025/06/06 12:56:32] ppocr DEBUG: cls num  : 1, elapsed : 0.004006147384643555
# [2025/06/06 12:56:32] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050633907318115234
# Frame 35 - Maximum Value = 60.0
# Frame 35 - min_angle = 246.02019342741656
# Frame 35 - max_angle = 344.21620246560417
# Frame 35 - pointer_angle = 16.74340233733115
# case (ii) :
# angle_range = 261.8039909618124
# val_angle = 229.27679109008542
# Frame 35 - Final Gauge Reading = 52.545445983715766
#
# 0: 384x640 1 clock, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 36 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_36.jpg
# [2025/06/06 12:56:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10918784141540527
# [2025/06/06 12:56:33] ppocr DEBUG: cls num  : 1, elapsed : 0.004006385803222656
# [2025/06/06 12:56:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05331134796142578
# Frame 36 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 36 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_36.jpg
# [2025/06/06 12:56:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11006927490234375
# [2025/06/06 12:56:33] ppocr DEBUG: cls num  : 1, elapsed : 0.005006551742553711
# [2025/06/06 12:56:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051247596740722656
# Frame 36 - Maximum Value = 60.0
# Frame 36 - min_angle = 246.1937402045578
# Frame 36 - max_angle = 344.2865503563212
# Frame 36 - pointer_angle = 13.939242725162195
# case (ii) :
# angle_range = 261.90718984823656
# val_angle = 232.25449747939558
# Frame 36 - Final Gauge Reading = 53.20690072249867
#
# 0: 384x640 1 clock, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 37 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_37.jpg
# [2025/06/06 12:56:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10918855667114258
# [2025/06/06 12:56:33] ppocr DEBUG: cls num  : 1, elapsed : 0.003999471664428711
# [2025/06/06 12:56:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05071854591369629
# Frame 37 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 37 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_37.jpg
# [2025/06/06 12:56:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10743045806884766
# [2025/06/06 12:56:33] ppocr DEBUG: cls num  : 1, elapsed : 0.006000041961669922
# [2025/06/06 12:56:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05149269104003906
# Frame 37 - Maximum Value = 60.0
# Frame 37 - min_angle = 244.64767322415597
# Frame 37 - max_angle = 342.3816727436135
# Frame 37 - pointer_angle = 5.703648928574821
# case (ii) :
# angle_range = 262.26600048054246
# val_angle = 238.94402429558113
# Frame 37 - Final Gauge Reading = 54.664506384610476
#
# 0: 384x640 1 clock, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 38 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_38.jpg
# [2025/06/06 12:56:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10923504829406738
# [2025/06/06 12:56:33] ppocr DEBUG: cls num  : 1, elapsed : 0.004006624221801758
# [2025/06/06 12:56:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051490068435668945
# Frame 38 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 38 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_38.jpg
# [2025/06/06 12:56:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1098320484161377
# [2025/06/06 12:56:34] ppocr DEBUG: cls num  : 1, elapsed : 0.004189014434814453
# [2025/06/06 12:56:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05014157295227051
# Frame 38 - Maximum Value = 60.0
# Frame 38 - min_angle = 245.18437738021439
# Frame 38 - max_angle = 343.2263718693807
# Frame 38 - pointer_angle = 3.3270906337341115
# case (ii) :
# angle_range = 261.9580055108337
# val_angle = 241.85728674648027
# Frame 38 - Final Gauge Reading = 55.39604402045531
#
# 0: 384x640 1 clock, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 1 maximum, 1 minimum, 1 tip, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised circular region 0 for frame 39 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_0_frame_39.jpg
# [2025/06/06 12:56:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10822033882141113
# [2025/06/06 12:56:34] ppocr DEBUG: cls num  : 1, elapsed : 0.0040035247802734375
# [2025/06/06 12:56:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.051480770111083984
# Frame 39 - Minimum Value = 0.0
# Saved denoised circular region 1 for frame 39 to: C:\Users\Harsh\Desktop\PTZ Camera Zoom with Gauge Detection\ocr_regions_video\denoised_circle_1_frame_39.jpg
# [2025/06/06 12:56:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.1076662540435791
# [2025/06/06 12:56:34] ppocr DEBUG: cls num  : 1, elapsed : 0.0040073394775390625
# [2025/06/06 12:56:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05079913139343262
# Frame 39 - Maximum Value = 60.0
# Frame 39 - min_angle = 245.35837703395933
# Frame 39 - max_angle = 344.03367769609355
# Frame 39 - pointer_angle = 357.24474687087024
# case (i) :
# angle_range = 261.3246993378658
# val_angle = 248.1136301630891
# Frame 39 - Final Gauge Reading = 56.96674614954108
#
# 0: 384x640 1 clock, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 22.1ms
# Speed: 2.1ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 23.2ms
# Speed: 2.0ms preprocess, 23.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 2 tips, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 24.3ms
# Speed: 3.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 24.3ms
# Speed: 3.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 24.3ms
# Speed: 3.0ms preprocess, 24.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 clock, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 base, 2 minimums, 1 tip, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
